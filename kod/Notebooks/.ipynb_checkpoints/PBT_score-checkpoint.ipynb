# %%
import sys
sys.path.append('../../src')
from modules import *
from columns import *
sys.path.append('../../src/python')
from random_funks import *

# %% [markdown]
# # Učitavanje podataka za BCF

# %%
# BCF_CAESAR # log(L/kg)
report_BCF_CAESAR = pd.read_csv('../../data/VEGA_QSAR_modeli/report_BCF_CAESAR.txt',index_col=0, sep='\t')
report_BCF_CAESAR = zamijeni_nazive_molekula(report_BCF_CAESAR)
BCF_CAESAR = report_BCF_CAESAR['Assessment'].values

# %%
# BCF_KNN # log(L/kg)
report_BCF_KNN = pd.read_csv('../../data/VEGA_QSAR_modeli/report_BCF_KNN.txt',index_col=0, sep='\t')
report_BCF_KNN = zamijeni_nazive_molekula(report_BCF_KNN)
BCF_KNN = report_BCF_KNN['Assessment'].values

# %%
# BCF_MEYLAN # log(L/kg)
report_BCF_MEYLAN = pd.read_csv('../../data/VEGA_QSAR_modeli/report_BCF_MEYLAN.txt',index_col=0, sep='\t')
report_BCF_MEYLAN = zamijeni_nazive_molekula(report_BCF_MEYLAN)
BCF_MEYLAN = report_BCF_MEYLAN['Assessment'].values

# %%
# BCF_ARNOTGOBAS # log(L/kg)
report_BCF_ARNOTGOBAS = pd.read_csv('../../data/VEGA_QSAR_modeli/report_BCF_ARNOTGOBAS.txt',index_col=0, sep='\t')
report_BCF_ARNOTGOBAS = zamijeni_nazive_molekula(report_BCF_ARNOTGOBAS)
BCF_ARNOTGOBAS = report_BCF_ARNOTGOBAS['Assessment'].values

# %%
BCF = pd.DataFrame({'Id': report_BCF_CAESAR['Id'], 
                     'BCF_CAESAR': BCF_CAESAR, 
                     'BCF_KNN': BCF_KNN, 
                     'BCF_MEYLAN': BCF_MEYLAN,
                     'BCF_ARNOTGOBAS': BCF_ARNOTGOBAS})
BCF.set_index('Id', inplace=True)
BCF_modified = extract_numeric_from_df(BCF)

# %% [markdown]
# # Rangirala svaki BCF posebno i average rank ili

# %%
# Rangiranje vrijednosti za svaki model
BCF_modified['BCF_CAESAR_rank'] = BCF_modified['BCF_CAESAR'].rank(ascending=False) # PRVI RANK DOBIJE NAJVEĆI log(l/kg)
BCF_modified['BCF_KNN_rank'] = BCF_modified['BCF_KNN'].rank(ascending=False)
BCF_modified['BCF_MEYLAN_rank'] = BCF_modified['BCF_MEYLAN'].rank(ascending=False)
BCF_modified['BCF_ARNOTGOBAS_rank'] = BCF_modified['BCF_ARNOTGOBAS'].rank(ascending=False)

# %%
#BCF_modified['BCF_mean'] = BCF_modified.mean(axis=1)

# %%
# Izračunavanje prosječnog ranga
average_rank = (BCF_modified['BCF_CAESAR_rank'] + 
                BCF_modified['BCF_KNN_rank'] + 
                BCF_modified['BCF_MEYLAN_rank'] +
                BCF_modified['BCF_ARNOTGOBAS_rank']) / 4

BCF_modified['BCF_average_rank'] = average_rank

# %% [markdown]
# # ili prvo napravim average i onda rank -> ovo ne!

# %%
# Izračunavanje prosječnog log(L/kg)
average_rank = (BCF_modified['BCF_CAESAR'] + 
                BCF_modified['BCF_KNN'] + 
                BCF_modified['BCF_MEYLAN'] +
                BCF_modified['BCF_ARNOTGOBAS']) / 4

# PCB-101          10.0              1.0                 12.0             6.250
# PCB-118          16.0              6.5                 14.0            11.375
# PCB-153           1.0              2.0                  1.0             4.000
# PCB-138           7.0              8.0                 16.0            10.750
# PCB-180           7.0             18.5                 15.0            15.125
# PCB-74           14.5              6.5                  5.0             7.625
# PCB-60           14.5             16.0                  4.0             9.750
# PCB-123          12.0              3.5                  9.0             6.625
# PCB-114          11.0              3.5                 10.0             6.625
# PCB-105          18.0              5.0                 11.0            12.500
# PCB-167           4.0              9.0                 18.0            10.750
# PCB-156           4.0             10.0                 17.0            10.750
# PCB-157           2.0             11.0                 19.0            11.000
# PCB-170           7.0             18.5                 20.0            16.375
# PCB-189           4.0             18.5                 22.0            16.125

# %% [markdown]
# # Učitavanje podataka za PERZISTENTNOST

# %%
report=pd.read_csv('../../data/VEGA_report.csv',index_col=0)

# %%
# REDYBIO_IRFMN # 
report_READYBIO_IRFMN = pd.read_csv('../../data/VEGA_QSAR_modeli/report_READYBIO_IRFMN.txt',index_col=0, sep='\t')
report_READYBIO_IRFMN = zamijeni_nazive_molekula(report_READYBIO_IRFMN)
READYBIO_IRFMN = report_READYBIO_IRFMN['Assessment'].values

# %%
# Persistence (sediment) quantitative model (IRFMN) # days
report_PERS_SED_QUANT = pd.read_csv('../../data/VEGA_QSAR_modeli/report_PERS_SED_QUANT.txt',index_col=0, sep='\t')
report_PERS_SED_QUANT = zamijeni_nazive_molekula(report_PERS_SED_QUANT)
PERS_SED_QUANT = report_PERS_SED_QUANT['Assessment'].values

# %%
# Persistence (sediment) model (IRFMN) # 
report_PERS_SED = pd.read_csv('../../data/VEGA_QSAR_modeli/report_PERS_SED.txt',index_col=0, sep='\t')
report_PERS_SED = zamijeni_nazive_molekula(report_PERS_SED)
PERS_SED = report_PERS_SED['Assessment'].values

# %%
# Persistence (water) quantitative model (IRFMN) # days
report_PERS_WATER_QUANT = pd.read_csv('../../data/VEGA_QSAR_modeli/report_PERS_WATER_QUANT.txt',index_col=0, sep='\t')
report_PERS_WATER_QUANT = zamijeni_nazive_molekula(report_PERS_WATER_QUANT )
PERS_WATER_QUANT  = report_PERS_WATER_QUANT ['Assessment'].values

# %%
# Persistence (water) model (IRFMN) # 
report_PERS_WAT = pd.read_csv('../../data/VEGA_QSAR_modeli/report_PERS_WAT.txt',index_col=0, sep='\t')
report_PERS_WAT = zamijeni_nazive_molekula(report_PERS_WAT)
PERS_WAT = report_PERS_WAT['Assessment'].values

# %%
# Air Half-Life (IRFMN-CORAL) # h
report_PERS_AIR_CORAL = pd.read_csv('../../data/VEGA_QSAR_modeli/report_PERS_AIR_CORAL.txt',index_col=0, sep='\t')
report_PERS_AIR_CORAL = zamijeni_nazive_molekula(report_PERS_AIR_CORAL)
PERS_AIR_CORAL = report_PERS_AIR_CORAL['Assessment'].values

# %%
PERZ = pd.DataFrame({'Id': report_READYBIO_IRFMN['Id'],
                     'READYBIO_IRFMN': READYBIO_IRFMN, 
                     'PERS_SED_QUANT': PERS_SED_QUANT, 
                     'PERS_SED': PERS_SED,
                     'PERS_WATER_QUANT': PERS_WATER_QUANT,
                    'PERS_WAT': PERS_WAT,
                    'PERS_AIR_CORAL': PERS_AIR_CORAL})
PERZ.set_index('Id', inplace=True)
PERZ_modified = extract_numeric_from_df(PERZ)  # JE LI BOLJE MOŽDA OSTAVITI SVE PA DA RANGIRA I LOW, MODERATE I GOOD SLAGANJE?

# %% [markdown]
# # Rangirala svaki PERZ posebno i average rank

# %%
# Rangiranje vrijednosti za svaki model
PERZ_modified['READYBIO_IRFMN_rank'] = PERZ_modified['READYBIO_IRFMN'].rank(ascending=False) # PRVI RANK DOBIJE NAJVEĆI 
PERZ_modified['PERS_SED_QUANT_rank'] = PERZ_modified['PERS_SED_QUANT'].rank(ascending=False)
PERZ_modified['PERS_SED_rank'] = PERZ_modified['PERS_SED'].rank(ascending=False)
PERZ_modified['PERS_WATER_QUANT_rank'] = PERZ_modified['PERS_WATER_QUANT'].rank(ascending=False)
PERZ_modified['PERS_WAT_rank'] = PERZ_modified['PERS_WAT'].rank(ascending=False)
PERZ_modified['PERS_AIR_CORAL_rank'] = PERZ_modified['PERS_AIR_CORAL'].rank(ascending=False)


# Izračunavanje prosječnog ranga
average_rank = (PERZ_modified['READYBIO_IRFMN_rank'] + 
                PERZ_modified['PERS_SED_QUANT_rank'] + 
                PERZ_modified['PERS_SED_rank'] +
                PERZ_modified['PERS_WATER_QUANT_rank'] +
               PERZ_modified['PERS_WAT_rank'] +
               PERZ_modified['PERS_AIR_CORAL_rank']) / 6

PERZ_modified['PERZ_average_rank'] = average_rank

# %%
PERZ_modified
# Out:
#                                             READYBIO_IRFMN  PERS_SED_QUANT  \
# Id
# Flu      Possible NON Readily Biodegradable (LOW reliab...          2292.0
# Pir      Possible NON Readily Biodegradable (LOW reliab...          2292.0
# BaA      Possible NON Readily Biodegradable (LOW reliab...          2292.0
# Kri      Possible NON Readily Biodegradable (LOW reliab...          2292.0
# BjF      Possible NON Readily Biodegradable (LOW reliab...          2292.0
# BbF      Possible NON Readily Biodegradable (LOW reliab...          2292.0
# BkF      Possible NON Readily Biodegradable (LOW reliab...          2292.0
# BaP      Possible NON Readily Biodegradable (LOW reliab...          2292.0
# DahA     Possible NON Readily Biodegradable (MODERATE r...          2292.0
# BghiP    Possible NON Readily Biodegradable (MODERATE r...          2292.0
# IP       Possible NON Readily Biodegradable (LOW reliab...          2292.0
# HCB           NON Readily Biodegradable (GOOD reliability)          2292.0
# α-HCH     NON Readily Biodegradable (MODERATE reliability)          2292.0
# β-HCH     NON Readily Biodegradable (MODERATE reliability)          2292.0
# γ-HCH     NON Readily Biodegradable (MODERATE reliability)          2292.0
# DDE            NON Readily Biodegradable (LOW reliability)          2292.0
# DDD       NON Readily Biodegradable (MODERATE reliability)          2292.0
# DDT       NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-28   Possible NON Readily Biodegradable (GOOD relia...          1206.0
# PCB-52   Possible NON Readily Biodegradable (GOOD relia...          2292.0
# PCB-101   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-118   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-153   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-138   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-180   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-74        NON Readily Biodegradable (GOOD reliability)          2292.0
# PCB-60        NON Readily Biodegradable (GOOD reliability)          2292.0
# PCB-123   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-114   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-105   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-167   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-156   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-157   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-170   NON Readily Biodegradable (MODERATE reliability)          2292.0
# PCB-189   NON Readily Biodegradable (MODERATE reliability)          2292.0
#
#                           PERS_SED  PERS_WATER_QUANT  \
# Id
# Flu        vP (EXPERIMENTAL value)              71.0
# Pir        vP (EXPERIMENTAL value)              71.0
# BaA        vP (EXPERIMENTAL value)              71.0
# Kri        vP (EXPERIMENTAL value)              71.0
# BjF          vP (GOOD reliability)              71.0
# BbF          vP (GOOD reliability)              71.0
# BkF        vP (EXPERIMENTAL value)              71.0
# BaP        vP (EXPERIMENTAL value)              71.0
# DahA       vP (EXPERIMENTAL value)              71.0
# BghiP      vP (EXPERIMENTAL value)              71.0
# IP           vP (GOOD reliability)              71.0
# HCB        vP (EXPERIMENTAL value)            2292.0
# α-HCH    vP (MODERATE reliability)              82.0
# β-HCH    vP (MODERATE reliability)              82.0
# γ-HCH    vP (MODERATE reliability)              82.0
# DDE        vP (EXPERIMENTAL value)            2292.0
# DDD      vP (MODERATE reliability)             800.0
# DDT        vP (EXPERIMENTAL value)             229.0
# PCB-28     vP (EXPERIMENTAL value)             399.0
# PCB-52     vP (EXPERIMENTAL value)            2292.0
# PCB-101    vP (EXPERIMENTAL value)            2292.0
# PCB-118      vP (GOOD reliability)            2292.0
# PCB-153      vP (GOOD reliability)            2292.0
# PCB-138      vP (GOOD reliability)            2292.0
# PCB-180    vP (EXPERIMENTAL value)            2292.0
# PCB-74       vP (GOOD reliability)            2292.0
# PCB-60       vP (GOOD reliability)            2292.0
# PCB-123      vP (GOOD reliability)            2292.0
# PCB-114      vP (GOOD reliability)            2292.0
# PCB-105      vP (GOOD reliability)            2292.0
# PCB-167      vP (GOOD reliability)            2292.0
# PCB-156      vP (GOOD reliability)            2292.0
# PCB-157      vP (GOOD reliability)            2292.0
# PCB-170      vP (GOOD reliability)            2292.0
# PCB-189      vP (GOOD reliability)            2292.0
#
#                           PERS_WAT  PERS_AIR_CORAL  READYBIO_IRFMN_rank  \
# Id
# Flu      P/vP (EXPERIMENTAL value)           2.230                  7.0
# Pir      P/vP (EXPERIMENTAL value)           2.230                  7.0
# BaA      P/vP (EXPERIMENTAL value)           2.230                  7.0
# Kri      P/vP (EXPERIMENTAL value)           2.230                  7.0
# BjF        P/vP (GOOD reliability)           2.815                  7.0
# BbF        P/vP (GOOD reliability)           2.453                  7.0
# BkF      P/vP (EXPERIMENTAL value)           2.230                  7.0
# BaP      P/vP (EXPERIMENTAL value)           2.230                  7.0
# DahA     P/vP (EXPERIMENTAL value)           2.230                  1.5
# BghiP    P/vP (EXPERIMENTAL value)           2.230                  1.5
# IP         P/vP (GOOD reliability)           2.536                  7.0
# HCB        vP (EXPERIMENTAL value)           4.260                 34.0
# α-HCH         vP (LOW reliability)           2.230                 22.5
# β-HCH         vP (LOW reliability)           2.230                 22.5
# γ-HCH         vP (LOW reliability)           2.230                 22.5
# DDE        vP (EXPERIMENTAL value)           2.230                 32.0
# DDD      vP (MODERATE reliability)           2.666                 22.5
# DDT        vP (EXPERIMENTAL value)           2.230                 22.5
# PCB-28     vP (EXPERIMENTAL value)           2.407                 12.5
# PCB-52     vP (EXPERIMENTAL value)           3.230                 12.5
# PCB-101    vP (EXPERIMENTAL value)           2.947                 22.5
# PCB-118      vP (GOOD reliability)           3.447                 22.5
# PCB-153      vP (GOOD reliability)           3.740                 22.5
# PCB-138      vP (GOOD reliability)           3.903                 22.5
# PCB-180    vP (EXPERIMENTAL value)           3.424                 22.5
# PCB-74       vP (GOOD reliability)           3.128                 34.0
# PCB-60       vP (GOOD reliability)           2.973                 34.0
# PCB-123      vP (GOOD reliability)           3.548                 22.5
# PCB-114      vP (GOOD reliability)           3.293                 22.5
# PCB-105      vP (GOOD reliability)           3.293                 22.5
# PCB-167      vP (GOOD reliability)           3.871                 22.5
# PCB-156      vP (GOOD reliability)           3.612                 22.5
# PCB-157      vP (GOOD reliability)           3.839                 22.5
# PCB-170      vP (GOOD reliability)           4.068                 22.5
# PCB-189      vP (GOOD reliability)           4.036                 22.5
#
#          PERS_SED_QUANT_rank  PERS_SED_rank  PERS_WATER_QUANT_rank  \
# Id
# Flu                     17.5           28.0                   30.0
# Pir                     17.5           28.0                   30.0
# BaA                     17.5           28.0                   30.0
# Kri                     17.5           28.0                   30.0
# BjF                     17.5           12.5                   30.0
# BbF                     17.5           12.5                   30.0
# BkF                     17.5           28.0                   30.0
# BaP                     17.5           28.0                   30.0
# DahA                    17.5           28.0                   30.0
# BghiP                   17.5           28.0                   30.0
# IP                      17.5           12.5                   30.0
# HCB                     17.5           28.0                    9.5
# α-HCH                   17.5            2.5                   23.0
# β-HCH                   17.5            2.5                   23.0
# γ-HCH                   17.5            2.5                   23.0
# DDE                     17.5           28.0                    9.5
# DDD                     17.5            2.5                   19.0
# DDT                     17.5           28.0                   21.0
# PCB-28                  35.0           28.0                   20.0
# PCB-52                  17.5           28.0                    9.5
# PCB-101                 17.5           28.0                    9.5
# PCB-118                 17.5           12.5                    9.5
# PCB-153                 17.5           12.5                    9.5
# PCB-138                 17.5           12.5                    9.5
# PCB-180                 17.5           28.0                    9.5
# PCB-74                  17.5           12.5                    9.5
# PCB-60                  17.5           12.5                    9.5
# PCB-123                 17.5           12.5                    9.5
# PCB-114                 17.5           12.5                    9.5
# PCB-105                 17.5           12.5                    9.5
# PCB-167                 17.5           12.5                    9.5
# PCB-156                 17.5           12.5                    9.5
# PCB-157                 17.5           12.5                    9.5
# PCB-170                 17.5           12.5                    9.5
# PCB-189                 17.5           12.5                    9.5
#
#          PERS_WAT_rank  PERS_AIR_CORAL_rank  PERZ_average_rank
# Id
# Flu               31.5                 29.0          23.833333
# Pir               31.5                 29.0          23.833333
# BaA               31.5                 29.0          23.833333
# Kri               31.5                 29.0          23.833333
# BjF               26.0                 18.0          18.500000
# BbF               26.0                 21.0          19.000000
# BkF               31.5                 29.0          23.833333
# BaP               31.5                 29.0          23.833333
# DahA              31.5                 29.0          22.916667
# BghiP             31.5                 29.0          22.916667
# IP                26.0                 20.0          18.833333
# HCB               21.0                  1.0          18.500000
# α-HCH              3.0                 29.0          16.250000
# β-HCH              3.0                 29.0          16.250000
# γ-HCH              3.0                 29.0          16.250000
# DDE               21.0                 29.0          22.833333
# DDD                1.0                 19.0          13.583333
# DDT               21.0                 29.0          23.166667
# PCB-28            21.0                 22.0          23.083333
# PCB-52            21.0                 14.0          17.083333
# PCB-101           21.0                 17.0          19.250000
# PCB-118           11.0                 10.0          13.833333
# PCB-153           11.0                  7.0          13.333333
# PCB-138           11.0                  4.0          12.833333
# PCB-180           21.0                 11.0          18.250000
# PCB-74            11.0                 15.0          16.583333
# PCB-60            11.0                 16.0          16.750000
# PCB-123           11.0                  9.0          13.666667
# PCB-114           11.0                 12.5          14.250000
# PCB-105           11.0                 12.5          14.250000
# PCB-167           11.0                  5.0          13.000000
# PCB-156           11.0                  8.0          13.500000
# PCB-157           11.0                  6.0          13.166667
# PCB-170           11.0                  2.0          12.500000
# PCB-189           11.0                  3.0          12.666667

# %% [markdown]
# # Učitavanje podataka za TOKSIČNOST

# %% [markdown]
# ## ukupni TU po lokacijama

# %%
toks=pd.read_csv('../../data/VEGA_QSAR_modeli/LC50_toks_average.csv',index_col=0)
toks = toks['TU_site_average_rank']

# %%
# ovo mi ne treba ukupni nego za svaku molekulu toksičnost! TU_sed od sva 3 modela

# %% [markdown]
# ## TU_sed za 35 molekula na 28 lokacija

# %%
toks_rank=pd.read_csv('../../data/VEGA_QSAR_modeli/toks_rank.csv')

# %%
toks_rank['Id'] = PERZ.index
toks_rank.set_index('Id', inplace=True)

# %%
# Izračunavanje prosječnog ranga
average_rank = (toks_rank['TU_sed_DM_rank_mean'] + 
                toks_rank['TU_sed_FM_rank_mean'] + 
                toks_rank['TU_sed_FA_rank_mean']) / 3

toks_rank['TU_sed_average_rank']=average_rank

# %%
toks_rank
# Out:
#          TU_sed_DM_rank_mean  TU_sed_FM_rank_mean  TU_sed_FA_rank_mean  \
# Id
# Flu                 1.000000             1.535714             1.571429
# Pir                 2.535714             7.250000             1.607143
# BaA                 8.000000            11.857143             5.535714
# Kri                 6.035714             9.892857             3.714286
# BjF                 8.321429             4.321429             8.250000
# BbF                 2.571429             1.500000             3.785714
# BkF                 9.464286             5.035714            10.285714
# BaP                 6.035714            10.000000             6.607143
# DahA               11.285714            14.357143            13.214286
# BghiP               6.250000             8.535714             9.535714
# IP                  5.214286             3.000000             8.678571
# HCB                28.000000            20.714286            18.392857
# α-HCH              13.482143             9.303571            11.017857
# β-HCH              14.910714            11.553571            12.410714
# γ-HCH              13.000000             9.000000            10.464286
# DDE                16.214286            14.250000            18.071429
# DDD                21.214286            34.000000            19.178571
# DDT                15.892857            17.071429            21.464286
# PCB-28             15.250000            16.750000            14.428571
# PCB-52             20.678571            19.107143            18.321429
# PCB-101            23.785714            21.178571            22.357143
# PCB-118            22.892857            23.821429            23.857143
# PCB-153            29.035714            25.428571            27.392857
# PCB-138            27.607143            24.464286            28.642857
# PCB-180            33.857143            31.678571            34.214286
# PCB-74             19.750000            21.750000            19.571429
# PCB-60             19.892857            22.000000            20.571429
# PCB-123            24.678571            25.500000            26.214286
# PCB-114            23.285714            25.214286            25.428571
# PCB-105            24.000000            23.500000            25.785714
# PCB-167            31.142857            30.892857            29.321429
# PCB-156            27.785714            29.678571            30.821429
# PCB-157            30.035714            30.142857            32.071429
# PCB-170            32.785714            31.678571            33.892857
# PCB-189            34.107143            34.035714            33.321429
#
#          TU_sed_average_rank
# Id
# Flu                 1.369048
# Pir                 3.797619
# BaA                 8.464286
# Kri                 6.547619
# BjF                 6.964286
# BbF                 2.619048
# BkF                 8.261905
# BaP                 7.547619
# DahA               12.952381
# BghiP               8.107143
# IP                  5.630952
# HCB                22.369048
# α-HCH              11.267857
# β-HCH              12.958333
# γ-HCH              10.821429
# DDE                16.178571
# DDD                24.797619
# DDT                18.142857
# PCB-28             15.476190
# PCB-52             19.369048
# PCB-101            22.440476
# PCB-118            23.523810
# PCB-153            27.285714
# PCB-138            26.904762
# PCB-180            33.250000
# PCB-74             20.357143
# PCB-60             20.821429
# PCB-123            25.464286
# PCB-114            24.642857
# PCB-105            24.428571
# PCB-167            30.452381
# PCB-156            29.428571
# PCB-157            30.750000
# PCB-170            32.785714
# PCB-189            33.821429

# %% [markdown]
# # PBT SCORE AVERAGE RANK

# %%
P = PERZ_modified['PERZ_average_rank']
B = BCF_modified['BCF_average_rank']
T = toks_rank['TU_sed_average_rank']

# %%
PBT_score = pd.DataFrame({'P': P, 
                          'B': B, 
                          'T': T})

# %%
#score_PBT = (PBT_score['P'] + PBT_score['B'] + PBT_score['T']) / 3

#PBT_score['score_PBT_ak'] = score_PBT

# kakvog smisla imaju ovi brojevi? nije mi ovo sjelo
# što je manji PBT_score to je toksičnije/gore

# %% [markdown]
# # PBT SCORE MEAN

# %%
score_PBT = PBT_score.mean(axis=1)
PBT_score['score_PBT'] = score_PBT
PBT_score
# Out:
#                  P       B          T  score_PBT
# Id
# Flu      23.833333  29.250   1.369048  18.150794
# Pir      23.833333  30.000   3.797619  19.210317
# BaA      23.833333  33.250   8.464286  21.849206
# Kri      23.833333  33.250   6.547619  21.210317
# BjF      18.500000  24.500   6.964286  16.654762
# BbF      19.000000  25.000   2.619048  15.539683
# BkF      23.833333  24.500   8.261905  18.865079
# BaP      23.833333  26.500   7.547619  19.293651
# DahA     22.916667  24.500  12.952381  20.123016
# BghiP    22.916667  28.000   8.107143  19.674603
# IP       18.833333  25.875   5.630952  16.779762
# HCB      18.500000  15.250  22.369048  18.706349
# α-HCH    16.250000  30.000  11.267857  19.172619
# β-HCH    16.250000  30.000  12.958333  19.736111
# γ-HCH    16.250000  30.000  10.821429  19.023810
# DDE      22.833333  11.750  16.178571  16.920635
# DDD      13.583333  17.000  24.797619  18.460317
# DDT      23.166667  10.500  18.142857  17.269841
# PCB-28   23.083333  15.750  15.476190  18.103175
# PCB-52   17.083333   9.500  19.369048  15.317460
# PCB-101  19.250000   6.250  22.440476  15.980159
# PCB-118  13.833333  11.375  23.523810  16.244048
# PCB-153  13.333333   4.000  27.285714  14.873016
# PCB-138  12.833333  10.750  26.904762  16.829365
# PCB-180  18.250000  15.125  33.250000  22.208333
# PCB-74   16.583333   7.625  20.357143  14.855159
# PCB-60   16.750000   9.750  20.821429  15.773810
# PCB-123  13.666667   6.625  25.464286  15.251984
# PCB-114  14.250000   6.625  24.642857  15.172619
# PCB-105  14.250000  12.500  24.428571  17.059524
# PCB-167  13.000000  10.750  30.452381  18.067460
# PCB-156  13.500000  10.750  29.428571  17.892857
# PCB-157  13.166667  11.000  30.750000  18.305556
# PCB-170  12.500000  16.375  32.785714  20.553571
# PCB-189  12.666667  16.125  33.821429  20.871032

# %% [markdown]
# # KONCENTRACIJA * PBT_score

# %%
# relativni PBT_score po lokacijama

# %%
data = pd.read_csv('../../data/PAH_PCB_OCP.csv',index_col=0)

# %%
konc = data.iloc[:,5:40].T
nazivi_lokacija = [dodaj_nazive_lokacija_i_rijeka(data, i, i) for i in range(len(konc.columns))]
konc.columns = nazivi_lokacija

# %%
PBT_rel=konc.multiply(PBT_score['score_PBT'], axis='index')

# %%
PBT_rel
# Out:
#          Kuželj-Gorski kotar - Kupa  Iševnica- Gorski kotar - Kupica  \
# Flu                       60.623651                        86.034762
# Pir                       72.615000                       134.664325
# BaA                       10.706111                         9.613651
# Kri                       48.571627                       233.525595
# BjF                       20.818452                         8.327381
# BbF                       92.461111                       246.303968
# BkF                        9.432540                        15.092063
# BaP                       21.415952                        10.997381
# DahA                       8.451667                        30.788214
# BghiP                     42.497143                       111.948492
# IP                        32.888333                        65.273274
# HCB                        0.374127                         0.374127
# α-HCH                      1.725536                         4.217976
# β-HCH                      2.170972                         2.960417
# γ-HCH                      0.380476                         7.990000
# DDE                        1.353651                         3.384127
# DDD                        0.369206                         0.369206
# DDT                        0.345397                         0.345397
# PCB-28                     2.715476                        10.318810
# PCB-52                     0.306349                         0.306349
# PCB-101                    0.319603                         0.319603
# PCB-118                    0.324881                         0.324881
# PCB-153                    0.297460                         0.297460
# PCB-138                    0.336587                         0.336587
# PCB-180                    0.444167                         0.444167
# PCB-74                     0.297103                         0.297103
# PCB-60                     0.315476                         0.315476
# PCB-123                    0.305040                         0.305040
# PCB-114                    0.303452                         0.303452
# PCB-105                    0.341190                         0.341190
# PCB-167                    0.361349                         0.361349
# PCB-156                    0.357857                         0.357857
# PCB-157                    0.366111                         0.366111
# PCB-170                    0.411071                         0.411071
# PCB-189                    0.417421                         0.417421
#
#          centar Karlovca - Kupa  ušće u Kupu - Korana  \
# PCB-60                         4.258929                          0.000000
# PCB-123                        0.305040                          0.305040
# PCB-114                        0.303452                          0.303452
# PCB-105                        5.117857                          0.341190
# PCB-167                        0.361349                          0.361349
# PCB-156                        0.536786                          0.357857
# PCB-157                        0.366111                          0.366111
# PCB-170                        1.644286                          0.411071
# PCB-189                        0.417421                          0.417421
#
#          Karlovac-Foginovo kupalište - Korana
# Flu                                221.621190
# Pir                                220.726548
# BaA                                 98.321429
# Kri                                157.592659
# BjF                                 52.962143
# BbF                                142.032698
# BkF                                 46.785397
# BaP                                110.166746
# DahA                                15.897183
# BghiP                               98.569762
# IP                                  91.953095
# HCB                                  0.561190
# α-HCH                                2.875893
# β-HCH                                0.789444
# γ-HCH                                2.092619
# DDE                                  1.861270
# DDD                                  2.399841
# DDT                                  0.345397
# PCB-28                               2.172381
# PCB-52                               0.306349
# PCB-101                              0.319603
# PCB-118                              0.324881
# PCB-153                              0.446190
# PCB-138                              0.673175
# PCB-180                              0.444167
# PCB-74                               0.297103
# PCB-60                               0.473214
# PCB-123                              0.305040
# PCB-114                              0.303452
# PCB-105                              0.341190
# PCB-167                              0.361349
# PCB-156                              0.357857
# PCB-157                              0.366111
# PCB-170                              0.411071
# PCB-189                              0.417421
#
# [35 rows x 28 columns]

# %%
# Kreiranje matrice podgrafikona
fig, axes = plt.subplots(nrows=7, ncols=4, figsize=(15, 20))

# Iscrtavanje histograma za svaku kolonu
for i, column in enumerate(PBT_rel.columns):
    ax = axes[i // 4, i % 4]  # Određuje poziciju podgrafikona
    PBT_rel[column].hist(ax=ax)
    ax.set_title(column)

# Sakrijte sve prazne podgrafikone
for i in range(len(PBT_rel.columns), 28):
    axes[i // 4, i % 4].axis('off')

plt.tight_layout()

# Spremanje grafikona
plt.savefig('../../data/VEGA_QSAR_modeli/histogram.jpg', format='jpg', dpi=1000)

# %%
log_relpbt=np.log10(PBT_rel)
# Out:
# /home/ivana/repozitorij/diplomski/ivana_dip/dipenv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)

# %%
# Kreiranje matrice podgrafikona
fig, axes = plt.subplots(nrows=7, ncols=4, figsize=(15, 20))

# Iscrtavanje histograma za svaku kolonu
for i, column in enumerate(log_relpbt.columns):
    ax = axes[i // 4, i % 4]  # Određuje poziciju podgrafikona
    log_relpbt[column].hist(ax=ax)
    ax.set_title(column)

# Sakrijte sve prazne podgrafikone
for i in range(len(log_relpbt.columns), 28):
    axes[i // 4, i % 4].axis('off')

plt.tight_layout()

# Spremanje grafikona
#plt.savefig('../../data/VEGA_QSAR_modeli/histogram.jpg', format='jpg', dpi=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-fe4c55e1ecec> in <module>
#       5 for i, column in enumerate(log_relpbt.columns):
#       6     ax = axes[i // 4, i % 4]  # Određuje poziciju podgrafikona
# ----> 7     log_relpbt[column].hist(ax=ax)
#       8     ax.set_title(column)
#       9
#
# ~/repozitorij/diplomski/ivana_dip/dipenv/lib/python3.10/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#     123     """
#     124     plot_backend = _get_plot_backend(backend)
# --> 125     return plot_backend.hist_series(
#     126         self,
#     127         by=by,
#
# ~/repozitorij/diplomski/ivana_dip/dipenv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     425         if legend:
#     426             kwds["label"] = self.name
# --> 427         ax.hist(values, bins=bins, **kwds)
#     428         if legend:
#     429             ax.legend()
#
# ~/repozitorij/diplomski/ivana_dip/dipenv/lib/python3.10/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/repozitorij/diplomski/ivana_dip/dipenv/lib/python3.10/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6857             # this will automatically overwrite bins,
#    6858             # so that each histogram uses the same bins
# -> 6859             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6860             tops.append(m)
#    6861         tops = np.array(tops, float)  # causes problems later if it's an int
#
# ~/repozitorij/diplomski/ivana_dip/dipenv/lib/python3.10/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, density, weights)
#     778     a, weights = _ravel_and_check_weights(a, weights)
#     779
# --> 780     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     781
#     782     # Histogram is an integer or a float array depending on the weights.
#
# ~/repozitorij/diplomski/ivana_dip/dipenv/lib/python3.10/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     424             raise ValueError('`bins` must be positive, when an integer')
#     425
# --> 426         first_edge, last_edge = _get_outer_edges(a, range)
#     427
#     428     elif np.ndim(bins) == 1:
#
# ~/repozitorij/diplomski/ivana_dip/dipenv/lib/python3.10/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     313                 'max must be larger than min in range parameter.')
#     314         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 315             raise ValueError(
#     316                 "supplied range of [{}, {}] is not finite".format(first_edge, last_edge))
#     317     elif a.size == 0:
#
# ValueError: supplied range of [-inf, 2.5683838994963146] is not finite

# %% [markdown]
# # TO_EXCEL

# %%
with pd.ExcelWriter("../../data/VEGA_QSAR_modeli/PBT_results.xlsx") as writer:
    PERZ_modified.to_excel(writer, sheet_name="Persistence (P)")
    BCF_modified.to_excel(writer, sheet_name="Bioaccumulation (B)")
    toks_rank.to_excel(writer, sheet_name="Toxicity (T)")
    PBT_score.to_excel(writer, sheet_name="PBT_score")
    PBT_rel.to_excel(writer, sheet_name="PBT_rel")

# %%
with pd.ExcelWriter("../../data/VEGA_QSAR_modeli/concentration_results.xlsx") as writer:
    konc.to_excel(writer, sheet_name="Concentration")

# %% [markdown]
# # SPEARMAN CORRRELATION

# %%
from scipy.stats import spearmanr

# Izračun Spearmanove korelacije
corr_PB, p_value_PB = spearmanr(P, B)
corr_PT, p_value_PT = spearmanr(P, T)
corr_BT, p_value_BT = spearmanr(B, T)
corr_PBT_P, p_value_PBT_P = spearmanr(score_PBT, P)
corr_PBT_B, p_value_PBT_B = spearmanr(score_PBT, B)
corr_PBT_T, p_value_PBT_T = spearmanr(score_PBT, T)

# %%
# Parovi za korelaciju
pairs = [('P', 'B', P, B), ('P', 'T', P, T), ('B', 'T', B, T), ('score_PBT', 'P', score_PBT, P), ('score_PBT', 'B', score_PBT, B), ('score_PBT', 'T', score_PBT, T)]

# Postavljanje figure za plotove
plt.figure(figsize=(15, 10))

for i, (var1, var2, data1, data2) in enumerate(pairs, 1):
    plt.subplot(2, 3, i)
    plt.scatter(data1, data2)
    corr, p_value = spearmanr(data1, data2)
    plt.title(f'{var1} vs {var2}\nSpearman Correlation: {corr:.3f}, p-value: {p_value:.3f}')
    plt.xlabel(var1)
    plt.ylabel(var2)

plt.tight_layout()
plt.show()

# %%
PBT_score.plot.scatter(x='B', y='T', s=np.square(P))

# %%
PBT_score.plot.scatter(x='P', y='T', s=np.square(B))

# %%
from scipy import stats
x=P
y=B
dof = len(x)-2  # len(x) == len(y)
dist = stats.t(df=dof)
t_vals = np.linspace(-5, 5, 100)
pdf = dist.pdf(t_vals)
fig, ax = plt.subplots(figsize=(8, 5))
def plot(ax):  # we'll re-use this
    ax.plot(t_vals, pdf)
    ax.set_title("Spearman's Rho Test Null Distribution")
    ax.set_xlabel("statistic")
    ax.set_ylabel("probability density")
plot(ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5))
plot(ax)
res=spearmanr(B, P)
rs = res.statistic  # original statistic
transformed = rs * np.sqrt(dof / ((rs+1.0)*(1.0-rs)))
pvalue = dist.cdf(-transformed) + dist.sf(transformed)
annotation = (f'p-value={pvalue:.4f}\n(shaded area)')
props = dict(facecolor='black', width=1, headwidth=5, headlength=8)
_ = ax.annotate(annotation, (2.7, 0.025), (3, 0.03), arrowprops=props)
i = t_vals >= transformed
ax.fill_between(t_vals[i], y1=0, y2=pdf[i], color='C0')
i = t_vals <= -transformed
ax.fill_between(t_vals[i], y1=0, y2=pdf[i], color='C0')
ax.set_xlim(-5, 5)
ax.set_ylim(0, 0.1)
plt.show()

# %%
res = stats.spearmanr(x, y, alternative='greater')
res.statistic
0.7000000000000001  # same statistic
fig, ax = plt.subplots(figsize=(8, 5))
plot(ax)
pvalue = dist.sf(transformed)
annotation = (f'p-value={pvalue:.6f}\n(shaded area)')
props = dict(facecolor='black', width=1, headwidth=5, headlength=8)
_ = ax.annotate(annotation, (3, 0.018), (3.5, 0.03), arrowprops=props)
i = t_vals >= transformed
ax.fill_between(t_vals[i], y1=0, y2=pdf[i], color='C0')
ax.set_xlim(1, 5)
ax.set_ylim(0, 0.1)
plt.show()

# %%
def statistic(x):  # explore all possible pairings by permuting `x`
    rs = stats.spearmanr(x, y).statistic  # ignore pvalue
    transformed = rs * np.sqrt(dof / ((rs+1.0)*(1.0-rs)))
    return transformed
ref = stats.permutation_test((x,), statistic, alternative='greater',
                             permutation_type='pairings')
fig, ax = plt.subplots(figsize=(8, 5))
plot(ax)
ax.hist(ref.null_distribution, np.linspace(-5, 5, 26),
        density=True)
ax.legend(['aymptotic approximation\n(many observations)',
           f'exact \n({len(ref.null_distribution)} permutations)'])
plt.show()
