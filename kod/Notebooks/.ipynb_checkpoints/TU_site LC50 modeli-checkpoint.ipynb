# %%
import sys
sys.path.append('../../src')
from modules import *
from columns import *
sys.path.append('../../src/python')
from random_funks import *

# %% [markdown]
# # Dataframe sa 3 modela za LC50

# %%
# DAPHNIA MAGNA EPA # mg/L
report_DM=pd.read_csv('../../data/VEGA_QSAR_modeli/report_DAPHNIA_EPA.txt',index_col=0, sep='\t')
report_DM = zamijeni_nazive_molekula(report_DM)
Daphnia_Magna_EPA = report_DM['Assessment'].values

# %%
# FATHEAD MINNOW EPA # mg/L
report_FM=pd.read_csv('../../data/VEGA_QSAR_modeli/report_FATHEAD_EPA.txt',index_col=0, sep='\t')
Fathead_Minnow_EPA = report_FM['Assessment'].values

# %%
# FISH ACUTE # mg/L
report_FA=pd.read_csv('../../data/VEGA_QSAR_modeli/report_FISH_LC50.txt',index_col=0, sep='\t')
Fish_acute_LC50 = report_FA['Assessment'].values

# %%
LC50_toks = pd.DataFrame({'Id': report_DM['Id'], 
                     'Daphnia_Magna_EPA_mg/L': Daphnia_Magna_EPA, 
                     'Fathead_Minnow_EPA_mg/L': Fathead_Minnow_EPA, 
                     'Fish_acute_LC50_mg/L': Fish_acute_LC50})
LC50_toks_modified = extract_numeric_from_df(LC50_toks)

# %%
LC50_toks_modified.to_csv('../../data/VEGA_QSAR_modeli/LC50_toks.csv', index=False)

# %% [markdown]
# # Izračun TU_site za sva 3 modela pojedinačno

# %%
data=pd.read_csv('../../data/PAH_PCB_OCP.csv',index_col=0)
report=pd.read_csv('../../data/VEGA_QSAR_modeli/LC50_toks.csv',index_col=0)
report_logP=pd.read_csv('../../data/VEGA_QSAR_modeli/logP_median.csv')

# %%
# DAPHNIA MAGNA EPA # mg/L
TU_site_DM = racunaj_TU_site_log10(data, report, report_logP, 0)

# %%
# FATHEAD MINNOW EPA # mg/L
TU_site_FM = racunaj_TU_site_log10(data, report, report_logP, 1)

# %%
# FISH ACUTE # mg/L
TU_site_FA = racunaj_TU_site_log10(data, report, report_logP, 2)

# %%
TU_site_LC50 = pd.DataFrame({'LOKACIJA': data['LOKACIJA'],
                             'RIJEKA': data['RIJEKA'],
                     'TU_site_DM': TU_site_DM, 
                     'TU_site_FM': TU_site_FM, 
                     'TU_site_FA': TU_site_FA})
TU_site_LC50
# Out:
#                                              LOKACIJA             RIJEKA  \
# 0                                 Kuželj-Gorski kotar               Kupa
# 1                              Iševnica- Gorski kotar             Kupica
# 2                                     centar Karlovca               Kupa
# 3                                         ušće u Kupu             Korana
# 4                                 Zagrebačka županija            Kupčina
# 5                                    Stubičke Toplice              Vidak
# 6                                               Istra              Mirna
# 7                                               Istra          Mala Huba
# 8                                               Istra         Boljunčica
# 9   Jurovo - Jurovski Brod (utok Lahinje - lijevi ...              Kupa
# 10                                              Ozalj              Kupa
# 11                                   Metković-Doljani            Neretva
# 12                                      Metković-Unka            Neretva
# 13                                      Metković-most            Neretva
# 14                                               ušće            Neretva
# 15                                             Mijači            Orljava
# 16                                       Striježevica             Brzaja
# 17                               Petrinja (kupalište)               Kupa
# 18                                 Sisak (Stari grad)               Kupa
# 19                                 Sisak (Stari grad)               Sava
# 20                  Zagreb (Savski Kamenji - toplana)               Sava
# 21                                  Prošćansko jezero  Plitvička jezera
# 22                               Belavići-kamp Slapić           Mrežnica
# 23                        Duga Resa-gradsko kupalište           Mrežnica
# 24                   Severin na Kupi-kupalište Klanac               Kupa
# 25                            Ozalj-gradsko kupalište               Kupa
# 26                            Slunj-kupalište Rastoke             Korana
# 27                        Karlovac-Foginovo kupalište             Korana
#
#     TU_site_DM  TU_site_FM  TU_site_FA
# 0    -5.509748   -4.977079   -5.906836
# 1    -6.014415   -5.422670   -6.334627
# 2    -4.486881   -3.975115   -4.921271
# 3    -6.152197   -5.749582   -6.533807
# 4    -6.751718   -6.248031   -7.130355
# 5    -5.725339   -5.271114   -6.155938
# 6    -6.540465   -5.901018   -6.989579
# 7    -6.008663   -5.335908   -6.435839
# 8    -6.179668   -5.580257   -6.612508
# 9    -6.339153   -5.741124   -6.738254
# 10   -6.412304   -5.918900   -6.750936
# 11   -6.009493   -5.456520   -6.439786
# 12   -5.970507   -5.474900   -6.360435
# 13   -4.776667   -4.310486   -5.222112
# 14   -6.683189   -6.181754   -7.077176
# 15   -6.591230   -6.141779   -7.031283
# 16   -5.929336   -5.622510   -6.340153
# 17   -4.668810   -4.253307   -5.100579
# 18   -5.715193   -5.141050   -6.170334
# 19   -5.636890   -5.092321   -6.057790
# 20   -4.447105   -3.996645   -4.864070
# 21   -6.314078   -5.776636   -6.765309
# 22   -6.868493   -6.163195   -7.290006
# 23   -6.161225   -5.685704   -6.616014
# 24   -6.177582   -5.603540   -6.565909
# 25   -6.304348   -5.649355   -6.722158
# 26   -7.141211   -6.547019   -7.522175
# 27   -6.073963   -5.648842   -6.491717

# %% [markdown]
# # Rangirala svaki posebno i average rank

# %%
# Rangiranje TU_site vrijednosti za svaki model
TU_site_LC50['TU_site_DM_rank'] = TU_site_LC50['TU_site_DM'].rank(ascending=False)
TU_site_LC50['TU_site_FM_rank'] = TU_site_LC50['TU_site_FM'].rank(ascending=False)
TU_site_LC50['TU_site_FA_rank'] = TU_site_LC50['TU_site_FA'].rank(ascending=False)

# Izračunavanje prosječnog ranga
average_rank = (TU_site_LC50['TU_site_DM_rank'] + TU_site_LC50['TU_site_FM_rank'] + TU_site_LC50['TU_site_FA_rank']) / 3

TU_site_LC50['TU_site_average_rank'] = average_rank
data['TU_site_average_rank'] = average_rank

# %%
TU_site_LC50.to_csv('../../data/VEGA_QSAR_modeli/LC50_toks_average.csv', index=False)

# %% [markdown]
# # PLOT NA KARTU

# %%
# PROBA

mapa = folium.Map(location=[data['LAT'].mean(), data['LON'].mean()], zoom_start=7)

# Dodavanje markera za svaku lokaciju
for index, row in data.iterrows():
    # Određivanje boje na temelju ranga
    if row['TU_site_average_rank'] <= 5:
        color = 'red'
    elif row['TU_site_average_rank'] <= 10:
        color = 'orange'
    else:
        color = 'green'

    folium.CircleMarker(
        location=[row['LAT'], row['LON']],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        popup=f"Lokacija: {index}<br>Prosj. rang toksičnosti: {row['TU_site_average_rank']:.2f}"
    ).add_to(mapa)

# Prikazivanje mape
#mapa.save('mapa_toksicnosti.html')

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0f6b0f64bcb7afdebc9e59cb9ede103 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0f6b0f64bcb7afdebc9e59cb9ede103&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f0f6b0f64bcb7afdebc9e59cb9ede103 = L.map(
#                 &quot;map_f0f6b0f64bcb7afdebc9e59cb9ede103&quot;,
#                 {
#                     center: [45.12004824999999, 15.854103321428571],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1f5b121a8b6f03044a238748a9f8e0f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0f6b0f64bcb7afdebc9e59cb9ede103);
#
#
#             var circle_marker_bbc7a1efc9b0fa4c4b17c88b529f30c9 = L.circleMarker(
#                 [45.47773400000001, 14.806545000000002],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f0f6b0f64bcb7afdebc9e59cb9ede103);
#
#
#         var popup_d5dabe034547ac756f1d052728e7ec7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ddbf428fcf20a6c52b5704643266ff7 = $(`&lt;div id=&quot;html_8ddbf428fcf20a6c52b5704643266ff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lokacija: 0&lt;br&gt;Prosj. rang toksičnosti: 5.00&lt;/div&gt;`)[0];
#                 popup_d5dabe034547ac756f1d052728e7ec7f.setContent(html_8ddbf428fcf20a6c52b5704643266ff7);
#
#
#
#         circle_marker_bbc7a1efc9b0fa4c4b17c88b529f30c9.bindPopup(popup_d5dabe034547ac756f1d052728e7ec7f)
#         ;
#
#
#
#
#             var circle_marker_e70844c90fcdd6af952a61e9b4b55d0d = L.circleMarker(
#                 [45.447729, 14.853218],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f0f6b0f64bcb7afdebc9e59cb9ede103);
#
#
#         var popup_dbc34af5f150f8358f0b2a9a361c9a1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0981bf65e7c891ac44b25518fa9db1f = $(`&lt;div id=&quot;html_b0981bf65e7c891ac44b25518fa9db1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lokacija: 1&lt;br&gt;Prosj. rang toksičnosti: 10.67&lt;/div&gt;`)[0];
#                 popup_dbc34af5f150f8358f0b2a9a361c9a1c.setContent(html_b0981bf65e7c891ac44b25518fa9db1f);
#
#
#
#         circle_marker_e70844c90fcdd6af952a61e9b4b55d0d.bindPopup(popup_dbc34af5f150f8358f0b2a9a361c9a1c)
#         ;
#
#
#
#
#             var circle_marker_415f685d45fca2b1bb0d927257c8ca51 = L.circleMarker(
#                 [45.49634, 15.551701],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f0f6b0f64bcb7afdebc9e59cb9ede103);
#
#
#         var popup_6d191e2c826b3b0c58bffc9a5176d66a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93e883ac735524bb9d75758a3776b417 = $(`&lt;div id=&quot;html_93e883ac735524bb9d75758a3776b417&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lokacija: 2&lt;br&gt;Prosj. rang toksičnosti: 1.67&lt;/div&gt;`)[0];
#                 popup_6d191e2c826b3b0c58bffc9a5176d66a.setContent(html_93e883ac735524bb9d75758a3776b417);
#
#
#
#         circle_marker_415f685d45fca2b1bb0d927257c8ca51.bindPopup(popup_6d191e2c826b3b0c58bffc9a5176d66a)
#         ;
#
#
#
#
#             var circle_marker_14f6838669325050b5980fb43f135f89 = L.circleMarker(
#                 [45.500745, 15.575217000000002],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&

# %% [markdown]
# # TU_sed sa FATHEAD MINNOW

# %%
TU_sed_FM = racunaj_TU_sed(data, report, report_logP, 1)
TU_sed_FM = pd.DataFrame(TU_sed_FM, columns=PAH_kol+OCP_kol+PCB_kol)

TU_sed_FM['LOKACIJA'] = data['LOKACIJA']
TU_sed_FM['RIJEKA'] = data['RIJEKA']

# %%
TU_sed_FM.to_csv('../../data/VEGA_QSAR_modeli/TU_sed_FM.csv', index=False)

# %%
TU_sed_FM = racunaj_TU_sed(data, report, report_logP, 1)
TU_sed_FM = pd.DataFrame(TU_sed_FM, columns=PAH_kol+OCP_kol+PCB_kol)

# %%
TU_sed_FM_rank = TU_sed_FM.T.rank(ascending=False)
TU_sed_FM_mean = TU_sed_FM_rank.mean(axis=1) # mean za svaku molekulu

# %% [markdown]
# # TU_sed sa DAPHNIA MAGNA

# %%
TU_sed_DM = racunaj_TU_sed(data, report, report_logP, 0)
TU_sed_DM = pd.DataFrame(TU_sed_DM, columns=PAH_kol+OCP_kol+PCB_kol)

# %%
TU_sed_DM_rank = TU_sed_DM.T.rank(ascending=False)
TU_sed_DM_mean = TU_sed_DM_rank.mean(axis=1)

# %% [markdown]
# # TU_sed sa FISH ACUTE

# %%
TU_sed_FA = racunaj_TU_sed(data, report, report_logP, 2)
TU_sed_FA = pd.DataFrame(TU_sed_FA, columns=PAH_kol+OCP_kol+PCB_kol)

# %%
TU_sed_FA_rank = TU_sed_FA.T.rank(ascending=False)
TU_sed_FA_mean = TU_sed_FA_rank.mean(axis=1)

# %% [markdown]
# # T za PBT_score

# %%
toks_rank = pd.DataFrame({
                     'TU_sed_DM_mean': TU_sed_DM_mean, 
                     'TU_sed_FM_mean': TU_sed_FM_mean, 
                     'TU_sed_FA_mean': TU_sed_FA_mean})

# %%
toks_rank.to_csv('../../data/VEGA_QSAR_modeli/toks_rank.csv', index=False)
